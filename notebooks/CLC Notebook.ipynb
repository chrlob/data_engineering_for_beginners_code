# %%
# %%sql
# show catalogs;
# Out:
#          catalog
# 0  spark_catalog

# %%
# %%sql
# use prod_db
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
# %%sql
# show catalogs;
# Out:
#          catalog
# 0          local
# 1  spark_catalog

# %%
# %%sql
# show schemas IN local;
# -- Catalog --> schema
# Out:
#   namespace
# 0      prod
# 1   prod_db

# %%
# %%sql
# show tables IN prod_db
# -- schema -> Table
# Out:
#    namespace                  tableName  isTemporary
# 0    prod_db                     orders        False
# 1    prod_db               fct_lineitem        False
# 2    prod_db                     nation        False
# 3    prod_db                   lineitem        False
# 4    prod_db     order_lineitem_metrics        False
# 5    prod_db               dim_customer        False
# 6    prod_db               stg_customer        False
# 7    prod_db                 stg_orders        False
# 8    prod_db                 stg_nation        False
# 9    prod_db              wide_lineitem        False
# 10   prod_db                   partsupp        False
# 11   prod_db  customer_outreach_metrics        False
# 12   prod_db                   supplier        False
# 13   prod_db               stg_lineitem        False
# 14   prod_db                       part        False
# 15   prod_db                   customer        False
# 16   prod_db                 fct_orders        False
# 17   prod_db                     region        False
# 18   prod_db                 stg_region        False
# 19   prod_db                wide_orders        False

# %%
# %%sql --show
# select * from prod_db.customer limit 2
# Out:
#    c_custkey              c_name                       c_address  c_nationkey  \
# 0          1  Customer#000000001               j5JsirBM9PsCy0O1m           15
# 1          2  Customer#000000002  487LW1dovn6Q4dMVymKwwLE9OKf3QG           13
#
#            c_phone c_acctbal c_mktsegment  \
# 0  25-989-741-2988    711.56     BUILDING
# 1  23-768-687-3665    121.65   AUTOMOBILE
#
#                                            c_comment
# 0  y final requests wake slyly quickly special ac...
# 1  y carefully regular foxes. slyly regular reque...

# %%
# %%sql
# DESCRIBE lineitem
# Out:
#            col_name      data_type comment
# 0        l_orderkey         bigint    None
# 1         l_partkey         bigint    None
# 2         l_suppkey         bigint    None
# 3      l_linenumber            int    None
# 4        l_quantity  decimal(15,2)    None
# 5   l_extendedprice  decimal(15,2)    None
# 6        l_discount  decimal(15,2)    None
# 7             l_tax  decimal(15,2)    None
# 8      l_returnflag         string    None
# 9      l_linestatus         string    None
# 10       l_shipdate           date    None
# 11     l_commitdate           date    None
# 12    l_receiptdate           date    None
# 13   l_shipinstruct         string    None
# 14       l_shipmode         string    None
# 15        l_comment         string    None

# %%
# %%sql
# DESCRIBE extended lineitem
# Out:
#                         col_name  \
# 0                     l_orderkey
# 1                      l_partkey
# 2                      l_suppkey
# 3                   l_linenumber
# 4                     l_quantity
# 5                l_extendedprice
# 6                     l_discount
# 7                          l_tax
# 8                   l_returnflag
# 9                   l_linestatus
# 10                    l_shipdate
# 11                  l_commitdate
# 12                 l_receiptdate
# 13                l_shipinstruct
# 14                    l_shipmode
# 15                     l_comment
# 16
# 17            # Metadata Columns
# 18                      _spec_id
# 19                    _partition
# 20                         _file
# 21                          _pos
# 22                      _deleted
# 23
# 24  # Detailed Table Information
# 25                          Name
# 26                          Type
# 27                      Location
# 28                      Provider
# 29                         Owner
# 30              Table Properties
# 31                    Statistics
#
#                                             data_type comment
# 0                                              bigint     NaN
# 1                                              bigint     NaN
# 2                                              bigint     NaN
# 3                                                 int     NaN
# 4                                       decimal(15,2)     NaN
# 5                                       decimal(15,2)     NaN
# 6                                       decimal(15,2)     NaN
# 7                                       decimal(15,2)     NaN
# 8                                              string     NaN
# 9                                              string     NaN
# 10                                               date     NaN
# 11                                               date     NaN
# 12                                               date     NaN
# 13                                             string     NaN
# 14                                             string     NaN
# 15                                             string     NaN
# 16
# 17
# 18                                                int
# 19                                           struct<>
# 20                                             string
# 21                                             bigint
# 22                                            boolean
# 23
# 24
# 25                             local.prod_db.lineitem
# 26                                            MANAGED
# 27    file:///home/airflow/warehouse/prod_db/lineitem
# 28                                            iceberg
# 29                                               root
# 30  [current-snapshot-id=7204212971023194945,forma...
# 31                       103298384 bytes, 600572 rows     NaN

# %%
# %%sql
# -- use * to specify all columns
# SELECT
#     *
# FROM
#     orders
# LIMIT
#     4
# Out:
#    o_orderkey  o_custkey o_orderstatus o_totalprice o_orderdate  \
# 0           1       3691             O    194029.55  1996-01-02
# 1           2       7801             O     60951.63  1996-12-01
# 2           3      12332             F    247296.05  1993-10-14
# 3           4      13678             O     53829.87  1995-10-11
#
#   o_orderpriority          o_clerk  o_shippriority  \
# 0           5-LOW  Clerk#000000951               0
# 1        1-URGENT  Clerk#000000880               0
# 2           5-LOW  Clerk#000000955               0
# 3           5-LOW  Clerk#000000124               0
#
#                                            o_comment
# 0                 ly express platelets. deposits acc
# 1  ve the furiously fluffy dependencies. carefull...
# 2   after the asymptotes. instructions cajole aft...
# 3  st the furiously bold pinto beans. furiously p...

# %%
# %%sql
# -- use column names to only read data from those columns
# SELECT
#     o_orderkey,
#     o_totalprice
# FROM
#     orders
# LIMIT
#     4
# Out:
#    o_orderkey o_totalprice
# 0           1    194029.55
# 1           2     60951.63
# 2           3    247296.05
# 3           4     53829.87

# %%
# %%sql
# -- all customer rows that have c_nationkey = 20
# SELECT
#     *
# FROM
#     customer
# WHERE
#     c_nationkey = 20
# LIMIT
#     10;
# Out:
#    c_custkey              c_name                                 c_address  \
# 0          6  Customer#000000006       g1s,pzDenUEBW3O,2 pxu0f9n2g64rJrt5E
# 1         81  Customer#000000081                        9jUFbrThIIeoUNd8 9
# 2        100  Customer#000000100                            MBy6qq3OEGpV4u
# 3        210  Customer#000000210                    ,XOlfSzkZDAkm96adR41j,
# 4        223  Customer#000000223                     MyQxUcG0P QCetmG00GlF
# 5        228  Customer#000000228  rZ1wxvHNByT71bUJWZjXMDROzlAch6FVu,dj8Zfq
# 6        247  Customer#000000247                        eSAW4XaakYFj2WToKU
# 7        278  Customer#000000278                          XHAfHlrYQM3elmhJ
# 8        285  Customer#000000285       rB6fTQKle64k3MvCCatad8DfMgR5OZA G4r
# 9        321  Customer#000000321           LX0SKs3jqo9wH1yixIdGWp2ItclDiuL
#
#    c_nationkey          c_phone c_acctbal c_mktsegment  \
# 0           20  30-114-968-4951   7638.57   AUTOMOBILE
# 1           20  30-165-277-3269   2023.71     BUILDING
# 2           20  30-749-445-4907   9889.89    FURNITURE
# 3           20  30-876-248-9750   7250.14    HOUSEHOLD
# 4           20  30-193-643-1517   7476.20     BUILDING
# 5           20  30-435-915-1603   6868.12    FURNITURE
# 6           20  30-151-905-3513   8495.92    HOUSEHOLD
# 7           20  30-445-570-5841   7621.56     BUILDING
# 8           20  30-235-130-1313   7276.72    FURNITURE
# 9           20  30-114-675-9153   7718.77    FURNITURE
#
#                                            c_comment
# 0   quickly silent asymptotes are slyly regular e...
# 1  s against the ironic packages haggle carefully...
# 2  dazzle carefully furiously final foxes. expres...
# 3              es cajole bravely across the blithely
# 4  xcuses. silent theodolites across the carefull...
# 5                      es. blithely permanent sentim
# 6  tes nag according to the blithe, even packages...
# 7  ely unusual accounts. stealthily special instr...
# 8   slyly according to the blithely special instr...
# 9  ng the final, bold requests. furiously regular...

# %%
# %%sql
# -- all customer rows that have c_nationkey = 20 or c_acctbal > 1000
# SELECT
#     *
# FROM
#     customer
# WHERE
#     c_nationkey = 20
#     OR c_acctbal > 1000
# LIMIT
#     10;
# Out:
#    c_custkey              c_name                              c_address  \
# 0          3  Customer#000000003                           fkRGN8nY4pkE
# 1          4  Customer#000000004                            4u58h fqkyE
# 2          6  Customer#000000006    g1s,pzDenUEBW3O,2 pxu0f9n2g64rJrt5E
# 3          7  Customer#000000007         8OkMVLQ1dK6Mbu6WG9 w4pLGQ n7MQ
# 4          8  Customer#000000008  j,pZ,Qp,qtFEo0r0c 92qobZtlhSuOqbE4JGV
# 5          9  Customer#000000009             vgIql8H6zoyuLMFNdAMLyE7 H9
# 6         10  Customer#000000010     Vf mQ6Ug9Ucf5OKGYq fsaX AtfsO7,rwY
# 7         12  Customer#000000012                          Sb4gxKs7W1AZa
# 8         13  Customer#000000013                Ez3ax0D5HnUbeUVSxoX8a8B
# 9         14  Customer#000000014                        h3GFMzeFfYiamqr
#
#    c_nationkey          c_phone c_acctbal c_mktsegment  \
# 0            1  11-719-748-3364   7498.12   AUTOMOBILE
# 1            4  14-128-190-5944   2866.83    MACHINERY
# 2           20  30-114-968-4951   7638.57   AUTOMOBILE
# 3           18  28-190-982-9759   9561.95   AUTOMOBILE
# 4           17  27-147-574-9335   6819.74     BUILDING
# 5            8  18-338-906-3675   8324.07    FURNITURE
# 6            5  15-741-346-9870   2753.54    HOUSEHOLD
# 7           13  23-791-276-1263   3396.49    HOUSEHOLD
# 8            3  13-761-547-5974   3857.34     BUILDING
# 9            1  11-845-129-3851   5266.30    FURNITURE
#
#                                            c_comment
# 0  fully. carefully silent instructions sleep alo...
# 1   sublate. fluffily even instructions are about th
# 2   quickly silent asymptotes are slyly regular e...
# 3  ounts. ironic, regular accounts sleep. final r...
# 4  riously final excuses sublate quickly among th...
# 5  ss pinto beans believe slyly quiet deposits-- ...
# 6                    g quickly after the evenly bold
# 7  ickly regular dependencies boost blithely arou...
# 8  quickly brave foxes. blithely even packages ag...
# 9                  r, express foxes cajole slyly aga

# %%
# %%sql
# -- all customer rows that have c_nationkey = 20 and c_acctbal > 1000
# SELECT
#     *
# FROM
#     customer
# WHERE
#     c_nationkey = 20
#     AND c_acctbal > 1000
# LIMIT
#     10;
# Out:
#    c_custkey              c_name                                 c_address  \
# 0          6  Customer#000000006       g1s,pzDenUEBW3O,2 pxu0f9n2g64rJrt5E
# 1         81  Customer#000000081                        9jUFbrThIIeoUNd8 9
# 2        100  Customer#000000100                            MBy6qq3OEGpV4u
# 3        210  Customer#000000210                    ,XOlfSzkZDAkm96adR41j,
# 4        223  Customer#000000223                     MyQxUcG0P QCetmG00GlF
# 5        228  Customer#000000228  rZ1wxvHNByT71bUJWZjXMDROzlAch6FVu,dj8Zfq
# 6        247  Customer#000000247                        eSAW4XaakYFj2WToKU
# 7        278  Customer#000000278                          XHAfHlrYQM3elmhJ
# 8        285  Customer#000000285       rB6fTQKle64k3MvCCatad8DfMgR5OZA G4r
# 9        321  Customer#000000321           LX0SKs3jqo9wH1yixIdGWp2ItclDiuL
#
#    c_nationkey          c_phone c_acctbal c_mktsegment  \
# 0           20  30-114-968-4951   7638.57   AUTOMOBILE
# 1           20  30-165-277-3269   2023.71     BUILDING
# 2           20  30-749-445-4907   9889.89    FURNITURE
# 3           20  30-876-248-9750   7250.14    HOUSEHOLD
# 4           20  30-193-643-1517   7476.20     BUILDING
# 5           20  30-435-915-1603   6868.12    FURNITURE
# 6           20  30-151-905-3513   8495.92    HOUSEHOLD
# 7           20  30-445-570-5841   7621.56     BUILDING
# 8           20  30-235-130-1313   7276.72    FURNITURE
# 9           20  30-114-675-9153   7718.77    FURNITURE
#
#                                            c_comment
# 0   quickly silent asymptotes are slyly regular e...
# 1  s against the ironic packages haggle carefully...
# 2  dazzle carefully furiously final foxes. expres...
# 3              es cajole bravely across the blithely
# 4  xcuses. silent theodolites across the carefull...
# 5                      es. blithely permanent sentim
# 6  tes nag according to the blithe, even packages...
# 7  ely unusual accounts. stealthily special instr...
# 8   slyly according to the blithely special instr...
# 9  ng the final, bold requests. furiously regular...

# %%
# %%sql
# -- all customer rows that have (c_nationkey = 20 and c_acctbal > 1000) or rows that have c_nationkey = 11
# SELECT
#     *
# FROM
#     customer
# WHERE
#     (
#         c_nationkey = 20
#         AND c_acctbal > 1000
# )
#     OR c_nationkey = 11
# LIMIT
#     10;
# Out:
#    c_custkey              c_name                                 c_address  \
# 0          6  Customer#000000006       g1s,pzDenUEBW3O,2 pxu0f9n2g64rJrt5E
# 1         52  Customer#000000052               UracAlAA8tSHL5V,poTZIOjh8o,
# 2         81  Customer#000000081                        9jUFbrThIIeoUNd8 9
# 3         84  Customer#000000084       GB3sUmv RRXV DPzeOSbGxMIF9Z4Eq9 rop
# 4        100  Customer#000000100                            MBy6qq3OEGpV4u
# 5        131  Customer#000000131             ItdUFrHPZlzjZ, fo03sG4topAKTV
# 6        134  Customer#000000134                6I1TTaoG7bbiogCqRcptG6BYme
# 7        148  Customer#000000148                    qJ8bFn4kwiit7RzwGrwo5m
# 8        190  Customer#000000190  mY30kK8AfsTGrx,L4zI   QlQnnmCUxikyc8QcZ7
# 9        210  Customer#000000210                    ,XOlfSzkZDAkm96adR41j,
#
#    c_nationkey          c_phone c_acctbal c_mktsegment  \
# 0           20  30-114-968-4951   7638.57   AUTOMOBILE
# 1           11  21-186-284-5998   5630.28    HOUSEHOLD
# 2           20  30-165-277-3269   2023.71     BUILDING
# 3           11  21-546-818-3802   5174.71    FURNITURE
# 4           20  30-749-445-4907   9889.89    FURNITURE
# 5           11  21-840-210-3572   8595.53    HOUSEHOLD
# 6           11  21-200-159-5932   4608.90     BUILDING
# 7           11  21-562-498-6636   2135.60    HOUSEHOLD
# 8           11  21-730-373-8193   1657.46   AUTOMOBILE
# 9           20  30-876-248-9750   7250.14    HOUSEHOLD
#
#                                            c_comment
# 0   quickly silent asymptotes are slyly regular e...
# 1  ts boost. carefully express waters across the ...
# 2  s against the ironic packages haggle carefully...
# 3  ounts. blithely express theodolites nag carefu...
# 4  dazzle carefully furiously final foxes. expres...
# 5  ly final Tiresias. slyly permanent theodolites...
# 6              ly regular dolphins haggle blithely.
# 7  e carefully pending ideas detect slyly along t...
# 8         y even packages engage furiously pending p
# 9              es cajole bravely across the blithely

# %%
# %%sql
# -- all customer rows where the name has a 381 in it
# SELECT
# *
# FROM
# customer
# WHERE
# c_name LIKE '%381%';
# Out:
#     c_custkey              c_name                                 c_address  \
# 0         381  Customer#000000381                          wXs5zN2nPHqPsfFO
# 1        1381  Customer#000001381     kAgLl7nUiPStCleWOiKevH3QAOhqtg9dVvrdN
# 2        2381  Customer#000002381   z7B43DZ7RGlkgEi3YaXfy,Aw2SZepYurvII41Do
# 3        3381  Customer#000003381                     03jULkpVTm92eKW24meIj
# 4        3810  Customer#000003810                        hlRTIO4e4HNahc8A D
# 5        3811  Customer#000003811                       b6vEJqifAgSbGhzTwTz
# 6        3812  Customer#000003812                                HGYp5dZtlA
# 7        3813  Customer#000003813             Aeky0En0JO5V1zRgFZ9EvCcBWaTmW
# 8        3814  Customer#000003814              FQ3lWCA3znooc3S SmDCfwqdn4R9
# 9        3815  Customer#000003815                    S5SIUeDCuVOKRTZqZ5M4CC
# 10       3816  Customer#000003816                                kFLu9DYSXH
# 11       3817  Customer#000003817     IWp4rgxgRxvUeHK2xtX8SEfGYmHYrCCpbBwXm
# 12       3818  Customer#000003818  yrvC8HiUJVCsu7MyFHcyTcmAP0NgEWnoXQgTAz36
# 13       3819  Customer#000003819                             TejxSl9G1aF1x
# 14       4381  Customer#000004381               MIQXH5W6Zsup5cVYfCtWupiJtgi
# 15       5381  Customer#000005381            bXQ,KuigJB1nASXN73PDwNOvXCIkp5
# 16       6381  Customer#000006381                     BKfk07DtN45gg2w4mMUK1
# 17       7381  Customer#000007381        yq7RXRmclCUi6wJspelKaEWSJ  TfycLah
# 18       8381  Customer#000008381     7kbg8wegbgGmgiW8OQ4SbJ8colXl6rpBmHudJ
# 19       9381  Customer#000009381                             BhXODcEOpwNg6
# 20      10381  Customer#000010381                              RLDSr5JOMK45
# 21      11381  Customer#000011381                          cHcQKKDGnWLbq48O
# 22      12381  Customer#000012381           hPUYchVeqkeLC1QCsGJXF5Fj6QDQhkd
# 23      13381  Customer#000013381                           TkAwDfheF4H3g9H
# 24      13810  Customer#000013810             KDptBRwrSNgIfqVU,Si2smGKFLFix
# 25      13811  Customer#000013811               XvajiqJbFBaY8IfkIPanJeDnrba
# 26      13812  Customer#000013812  WuM0MP,N22TPjuHnUzDbcyJF86fkycoa8L7xPsKK
# 27      13813  Customer#000013813                           Xh5saiXGJkv5 lL
# 28      13814  Customer#000013814                  PnsbC4EN7J4TZ30 yPPlI8xh
# 29      13815  Customer#000013815                        UHXyxzMMNwV dIRAGo
# 30      13816  Customer#000013816                   XX Nlht,5lD6vroOC75qAS
# 31      13817  Customer#000013817            eg1g5BqcUMPqvGy9oY7bjVe7nj6NsH
# 32      13818  Customer#000013818               r17Nf8Y8iLfBKIGP6zJUrWl5K3g
# 33      13819  Customer#000013819  9MlFsiIsVNrVT8jJKRp30wISV5sNdXAwIT85F8S
# 34      14381  Customer#000014381                             jakuN8Gt0SJNE
#
#     c_nationkey          c_phone c_acctbal c_mktsegment  \
# 0             5  15-860-208-7093   9931.71     BUILDING
# 1            22  32-418-900-6494    367.82     BUILDING
# 2             5  15-493-990-8133    412.99    FURNITURE
# 3            13  23-441-750-5088   2473.54   AUTOMOBILE
# 4            18  28-881-994-8196   9906.80    FURNITURE
# 5            22  32-962-997-2221   5697.04    FURNITURE
# 6            14  24-653-654-5032   4204.53    FURNITURE
# 7             6  16-983-191-7833   -494.03    HOUSEHOLD
# 8            20  30-833-732-5401   -207.83   AUTOMOBILE
# 9            19  29-968-870-7672   2887.99    FURNITURE
# 10            6  16-806-750-3968   4353.05   AUTOMOBILE
# 11           16  26-142-669-5787   9766.42   AUTOMOBILE
# 12            7  17-983-218-3716    346.99   AUTOMOBILE
# 13            4  14-964-709-5782   -210.31     BUILDING
# 14            2  12-570-797-1472   2542.55    HOUSEHOLD
# 15            5  15-700-184-7619   4130.88    MACHINERY
# 16            7  17-877-502-9214   7346.88    HOUSEHOLD
# 17           20  30-666-139-1602     73.39     BUILDING
# 18            0  10-177-308-9094   6674.59   AUTOMOBILE
# 19           17  27-708-588-6706   4788.15    HOUSEHOLD
# 20           15  25-294-314-6077    106.15    FURNITURE
# 21            7  17-652-294-7849   1959.81    MACHINERY
# 22           13  23-989-969-2819   1172.56    HOUSEHOLD
# 23            9  19-465-107-1496   3221.83    HOUSEHOLD
# 24           18  28-953-486-1222   5133.48     BUILDING
# 25           19  29-964-589-6640   3436.54    MACHINERY
# 26            0  10-571-845-2630   5982.87   AUTOMOBILE
# 27           21  31-140-142-6191   1190.11    MACHINERY
# 28           17  27-767-457-2550   2131.39    FURNITURE
# 29           11  21-606-813-1389   4240.37    FURNITURE
# 30           17  27-501-367-6604   7844.29   AUTOMOBILE
# 31            3  13-978-449-6295   2094.32    FURNITURE
# 32           15  25-948-173-6359   8239.56    HOUSEHOLD
# 33           12  22-868-584-6588   1312.29     BUILDING
# 34           21  31-449-680-6297   1915.30    FURNITURE
#
#                                             c_comment
# 0   ithely along the regular, regular theodolites....
# 1           posits sleep carefully around the slyly e
# 2   ul requests use slyly quickly even deposits. s...
# 3   er the carefully bold multipliers doze blithel...
# 4                    bold requests after the furiousl
# 5   he carefully special packages. regular deposit...
# 6                  y ironic requests believe blithely
# 7     rding to the express foxes. bold platelets main
# 8              ounts alongside of the fluffily pendin
# 9         ccounts. fluffily bold requests sleep furio
# 10  g the carefully ironic asymptotes. furiously i...
# 11  es until the bold instructions wake quickly ca...
# 12   theodolites. special instructions are blithel...
# 13  os. excuses boost quickly across the carefully...
# 14         r deposits. carefully even packages along
# 15  es. carefully ironic ideas sleep blithely abou...
# 16  inal asymptotes boost. bold, ironic requests a...
# 17  fluffily special requests are about the fluffi...
# 18  uests against the carefully bold excuses sleep...
# 19  sual hockey players use above the final packag...
# 20  r the furiously unusual pinto beans. blithely ...
# 21   structions. slyly ironic requests play furiously
# 22  cies cajole carefully. unusual, ironic ideas b...
# 23  efully regular foxes. ironic platelets sleep a...
# 24  lithely. slyly ironic pinto beans nag. ironic,...
# 25  ly regular theodolites: courts nag blithely. b...
# 26  lar ideas use carefully alongside of the fluff...
# 27  te blithely even instructions. regular, final ...
# 28   instructions according to the furious, ironic...
# 29  special deposits. carefully daring requests sl...
# 30  ully final excuses. carefully unusual accounts...
# 31  slyly. even theodolites nag regularly-- furiou...
# 32  cial courts. excuses sleep quickly regular acc...
# 33             ackages. carefully special pinto beans
# 34   the even accounts cajole blithely furiously e...

# %%
# %%sql
# -- all customer rows where the name ends with a 381
# SELECT
# *
# FROM
# customer
# WHERE
# c_name LIKE '%381';
# Out:
#     c_custkey              c_name                                c_address  \
# 0         381  Customer#000000381                         wXs5zN2nPHqPsfFO
# 1        1381  Customer#000001381    kAgLl7nUiPStCleWOiKevH3QAOhqtg9dVvrdN
# 2        2381  Customer#000002381  z7B43DZ7RGlkgEi3YaXfy,Aw2SZepYurvII41Do
# 3        3381  Customer#000003381                    03jULkpVTm92eKW24meIj
# 4        4381  Customer#000004381              MIQXH5W6Zsup5cVYfCtWupiJtgi
# 5        5381  Customer#000005381           bXQ,KuigJB1nASXN73PDwNOvXCIkp5
# 6        6381  Customer#000006381                    BKfk07DtN45gg2w4mMUK1
# 7        7381  Customer#000007381       yq7RXRmclCUi6wJspelKaEWSJ  TfycLah
# 8        8381  Customer#000008381    7kbg8wegbgGmgiW8OQ4SbJ8colXl6rpBmHudJ
# 9        9381  Customer#000009381                            BhXODcEOpwNg6
# 10      10381  Customer#000010381                             RLDSr5JOMK45
# 11      11381  Customer#000011381                         cHcQKKDGnWLbq48O
# 12      12381  Customer#000012381          hPUYchVeqkeLC1QCsGJXF5Fj6QDQhkd
# 13      13381  Customer#000013381                          TkAwDfheF4H3g9H
# 14      14381  Customer#000014381                            jakuN8Gt0SJNE
#
#     c_nationkey          c_phone c_acctbal c_mktsegment  \
# 0             5  15-860-208-7093   9931.71     BUILDING
# 1            22  32-418-900-6494    367.82     BUILDING
# 2             5  15-493-990-8133    412.99    FURNITURE
# 3            13  23-441-750-5088   2473.54   AUTOMOBILE
# 4             2  12-570-797-1472   2542.55    HOUSEHOLD
# 5             5  15-700-184-7619   4130.88    MACHINERY
# 6             7  17-877-502-9214   7346.88    HOUSEHOLD
# 7            20  30-666-139-1602     73.39     BUILDING
# 8             0  10-177-308-9094   6674.59   AUTOMOBILE
# 9            17  27-708-588-6706   4788.15    HOUSEHOLD
# 10           15  25-294-314-6077    106.15    FURNITURE
# 11            7  17-652-294-7849   1959.81    MACHINERY
# 12           13  23-989-969-2819   1172.56    HOUSEHOLD
# 13            9  19-465-107-1496   3221.83    HOUSEHOLD
# 14           21  31-449-680-6297   1915.30    FURNITURE
#
#                                             c_comment
# 0   ithely along the regular, regular theodolites....
# 1           posits sleep carefully around the slyly e
# 2   ul requests use slyly quickly even deposits. s...
# 3   er the carefully bold multipliers doze blithel...
# 4          r deposits. carefully even packages along
# 5   es. carefully ironic ideas sleep blithely abou...
# 6   inal asymptotes boost. bold, ironic requests a...
# 7   fluffily special requests are about the fluffi...
# 8   uests against the carefully bold excuses sleep...
# 9   sual hockey players use above the final packag...
# 10  r the furiously unusual pinto beans. blithely ...
# 11   structions. slyly ironic requests play furiously
# 12  cies cajole carefully. unusual, ironic ideas b...
# 13  efully regular foxes. ironic platelets sleep a...
# 14   the even accounts cajole blithely furiously e...

# %%
# %%sql
# -- all customer rows where the name starts with a 381
# SELECT
# *
# FROM
# customer
# WHERE
# c_name LIKE '381%';
# Out:
# Empty DataFrame
# Columns: [c_custkey, c_name, c_address, c_nationkey, c_phone, c_acctbal, c_mktsegment, c_comment]
# Index: []

# %%
# %%sql
# -- all customer rows where the name has a combination of any character and 9 and 1
# SELECT
# *
# FROM
# customer
# WHERE
# c_name LIKE '%_91%'
# Out:
#      c_custkey              c_name                              c_address  \
# 0           91  Customer#000000091  9Sce2m BjvDdjQkqMx8UnrUsJkk1IBAvZPTsA
# 1          191  Customer#000000191                      cZMo3 b4GwZtUmdbw
# 2          291  Customer#000000291                       2FfdPluDa2fxPaRh
# 3          391  Customer#000000391                    BZ,850WgpZ0YSFs79Sb
# 4          491  Customer#000000491             AXsbcyMDujG,CAiEu4FmufbZ1k
# ..         ...                 ...                                    ...
# 394      14916  Customer#000014916                  035xAZ1oPhlAIihAkD092
# 395      14917  Customer#000014917                 cZ8cssZ58Txxjpl0d7mDMd
# 396      14918  Customer#000014918       hM0AjxfaIsjxOsn,SKtdkwp7,GARVKxx
# 397      14919  Customer#000014919    3bsc2D8rVgoBTGuACBsmBj xML5n5BHhFN9
# 398      14991  Customer#000014991   anYPB3mfutBIEfL8U5julAvLCF27RK39eOFX
#
#      c_nationkey          c_phone c_acctbal c_mktsegment  \
# 0              8  18-239-400-3677   4643.14   AUTOMOBILE
# 1             16  26-811-707-6869   2945.16     BUILDING
# 2              8  18-657-656-2318   4261.68    HOUSEHOLD
# 3             11  21-604-451-4462   4801.30    HOUSEHOLD
# 4              0  10-856-259-7548    785.37   AUTOMOBILE
# ..           ...              ...       ...          ...
# 394           15  25-400-635-5281   5961.85     BUILDING
# 395           13  23-815-258-6266   -139.26    FURNITURE
# 396            6  16-780-361-1053    437.89   AUTOMOBILE
# 397           22  32-766-874-8919   9541.68    HOUSEHOLD
# 398            7  17-617-866-6744   1258.32    HOUSEHOLD
#
#                                              c_comment
# 0    yly ironic foxes lose slyly pending asymptotes...
# 1                  daringly quickly ironic foxes. care
# 2    ld deposits. regularly ironic pinto beans cajo...
# 3    tions wake about the blithely final instructio...
# 4    ly final, even hockey players. carefully final...
# ..                                                 ...
# 394  inal accounts of the quickly ironic patterns s...
# 395  against the carefully even dependencies believ...
# 396  ltipliers dazzle after the carefully even pack...
# 397  sleep carefully even asymptotes. furiously spe...
# 398  e quickly unusual foxes. theodolites nag after...
#
# [399 rows x 8 columns]

# %%
# %%sql
# -- all customer rows which have nationkey = 10 or nationkey = 20
# SELECT
# *
# FROM
# customer
# WHERE
# c_nationkey IN (10,20);
# Out:
#      c_custkey              c_name                                c_address  \
# 0            6  Customer#000000006      g1s,pzDenUEBW3O,2 pxu0f9n2g64rJrt5E
# 1           16  Customer#000000016                      P2IQMff18ercaYrO,40
# 2           41  Customer#000000041          jeREsFtCuMqEwdvTFqTkY2NzGRYDG1m
# 3           49  Customer#000000049    PdKqM4TlA OLTjaeRmvH7QWDu80USfslgqutF
# 4           55  Customer#000000055   ti9p9XgdmFsjsQI6XQrISDUMFAusnmKS SBoCE
# ..         ...                 ...                                      ...
# 995      12731  Customer#000012731             swFK5R H3D5O0KyCLDVCFzRAn,qe
# 996      12744  Customer#000012744     qSvQ7ewh3NdzAEUw 34oS0C5hThl8oDV9cPs
# 997      12746  Customer#000012746                  9tXOYBDc9kN,VkWbt5hOcwO
# 998      12798  Customer#000012798                XIWKSftwGctGvoQcVdCOcfIQ,
# 999      12803  Customer#000012803  XkLopEcbWOwdBUTy6CxtBaCzAdeg2Gdg3Nsh4nP
#
#      c_nationkey          c_phone c_acctbal c_mktsegment  \
# 0             20  30-114-968-4951   7638.57   AUTOMOBILE
# 1             10  20-781-609-3107   4681.03    FURNITURE
# 2             10  20-917-711-4011    270.95    HOUSEHOLD
# 3             10  20-908-631-4424   4573.94    FURNITURE
# 4             10  20-180-440-8525   4572.11    MACHINERY
# ..           ...              ...       ...          ...
# 995           20  30-217-649-3797   9198.53     BUILDING
# 996           20  30-536-921-9179   7123.50    MACHINERY
# 997           20  30-625-211-9755   3241.37    HOUSEHOLD
# 998           10  20-238-557-6455   2628.36   AUTOMOBILE
# 999           20  30-782-739-9002   2261.81    FURNITURE
#
#                                              c_comment
# 0     quickly silent asymptotes are slyly regular e...
# 1    ests cajole. pinto beans detect slyly. final p...
# 2    uctions wake carefully pending deposits: pinto...
# 3    quests haggle! furiously unusual theodolites c...
# 4    dolites. bold instructions wake fluffily regul...
# ..                                                 ...
# 995     deposits. ironic, ironic accounts are. express
# 996  er the slyly even ideas wake along the stealth...
# 997  beans nag furiously bold, express deposits? ca...
# 998  telets are ideas. furiously even packages nag ...
# 999  egular, permanent dolphins. carefully express ...
#
# [1000 rows x 8 columns]

# %%
# %%sql
# -- all customer rows which have do not nationkey as 10 or 20
# SELECT
# *
# FROM
# customer
# WHERE
# c_nationkey NOT IN (10,20);
# Out:
#      c_custkey              c_name                          c_address  \
# 0            1  Customer#000000001                  j5JsirBM9PsCy0O1m
# 1            2  Customer#000000002     487LW1dovn6Q4dMVymKwwLE9OKf3QG
# 2            3  Customer#000000003                       fkRGN8nY4pkE
# 3            4  Customer#000000004                        4u58h fqkyE
# 4            5  Customer#000000005       hwBtxkoBF qSW4KrIk5U 2B1AU7H
# ..         ...                 ...                                ...
# 995       1090  Customer#000001090                         cYhnjm5uH6
# 996       1091  Customer#000001091           XtMTviXK6RZ91oBw7ynIT4z0
# 997       1092  Customer#000001092                       1CqAYgU,JHQS
# 998       1093  Customer#000001093  gc0RApbiH84 IpAbzqc3g agMOaS6cVKP
# 999       1094  Customer#000001094   dls,MNN7EbF3GYrY3eRwSeOBZYd5o,cg
#
#      c_nationkey          c_phone c_acctbal c_mktsegment  \
# 0             15  25-989-741-2988    711.56     BUILDING
# 1             13  23-768-687-3665    121.65   AUTOMOBILE
# 2              1  11-719-748-3364   7498.12   AUTOMOBILE
# 3              4  14-128-190-5944   2866.83    MACHINERY
# 4              3  13-750-942-6364    794.47    HOUSEHOLD
# ..           ...              ...       ...          ...
# 995           15  25-711-934-6343   5212.43   AUTOMOBILE
# 996           17  27-336-955-4882   -710.53     BUILDING
# 997           15  25-766-175-4580   2004.15    HOUSEHOLD
# 998           24  34-931-911-6156   -273.96    HOUSEHOLD
# 999            2  12-234-721-9871   2544.49    MACHINERY
#
#                                              c_comment
# 0    y final requests wake slyly quickly special ac...
# 1    y carefully regular foxes. slyly regular reque...
# 2    fully. carefully silent instructions sleep alo...
# 3     sublate. fluffily even instructions are about th
# 4    equests haggle furiously against the pending p...
# ..                                                 ...
# 995                  al dependencies. slowly ironic id
# 996  onic accounts are quickly. ironic instructions...
# 997      ages; slyly express pinto beans haggle alongs
# 998  ests detect fluffily slyly fluffy ideas? fluff...
# 999  structions among the furiously final pinto bea...
#
# [1000 rows x 8 columns]

# %%
# %%sql
# SELECT
#     COUNT(*)
# FROM
#     customer;
# -- 15,000
# Out:
#    count(1)
# 0     15000

# %%
# %%sql
# SELECT
#     COUNT(*)
# FROM
#     lineitem;
# -- 600,572
# Out:
#    count(1)
# 0    600572

# %%
# %%sql
# -- Will show the first ten customer records with the lowest custkey
# -- rows are ordered in ASC order by default
# SELECT
# *
# FROM
# orders
# ORDER BY
# o_custkey
# LIMIT
# 10;
# Out:
#    o_orderkey  o_custkey o_orderstatus o_totalprice o_orderdate  \
# 0       36422          1             O    268835.44  1997-03-04
# 1      224167          1             O     81485.84  1996-05-08
# 2      135943          1             F    263247.54  1993-06-22
# 3      164711          1             F    283261.47  1992-04-26
# 4      287619          1             O     11925.85  1996-12-26
# 5      385825          1             O    235155.22  1995-11-01
# 6      430243          1             F     35523.05  1994-12-24
# 7      454791          1             F     83779.26  1992-04-19
# 8      579908          1             O     45744.09  1996-12-09
# 9       52263          2             F     36433.77  1994-05-08
#
#    o_orderpriority          o_clerk  o_shippriority  \
# 0         3-MEDIUM  Clerk#000000532               0
# 1            5-LOW  Clerk#000000657               0
# 2  4-NOT SPECIFIED  Clerk#000000685               0
# 3         3-MEDIUM  Clerk#000000361               0
# 4            5-LOW  Clerk#000000854               0
# 5           2-HIGH  Clerk#000000465               0
# 6  4-NOT SPECIFIED  Clerk#000000121               0
# 7         1-URGENT  Clerk#000000815               0
# 8            5-LOW  Clerk#000000783               0
# 9  4-NOT SPECIFIED  Clerk#000000080               0
#
#                                            o_comment
# 0  s. slyly regular platelets doubt slyly after t...
# 1  ithely unusual deposits. slyly pending somas w...
# 2                    ironic ideas affix furiously ac
# 3                       fully special ideas. fluffil
# 4  t pending requests. carefully ironic sheaves a...
# 5  ly express accounts. special requests accordin...
# 6    e slyly along the furiously pending attainments
# 7         ccounts sleep carefully along the slyly ev
# 8  t packages hinder bold, even dolphins. slyly i...
# 9  uests dazzle blithely against the final, final...

# %%
# %%sql
# -- Will show the first ten customer's records with the highest custkey
# SELECT
#   *
# FROM
#   orders
# ORDER BY
#   o_custkey DESC
# LIMIT
#   10;
# Out:
#    o_orderkey  o_custkey o_orderstatus o_totalprice o_orderdate  \
# 0      134848      14999             O    170212.14  1998-03-07
# 1      129605      14999             P    172005.93  1995-03-27
# 2       94817      14999             F    193676.15  1992-08-02
# 3       67298      14999             O    296795.91  1995-09-15
# 4      157894      14999             F     76068.72  1992-06-08
# 5      158657      14999             O    164096.58  1998-02-28
# 6      178087      14999             F    320537.50  1994-04-16
# 7      190498      14999             O    102768.22  1998-03-13
# 8      215168      14999             F    202248.65  1992-02-24
# 9      233956      14999             F    219593.16  1994-03-28
#
#    o_orderpriority          o_clerk  o_shippriority  \
# 0           2-HIGH  Clerk#000000669               0
# 1         3-MEDIUM  Clerk#000000578               0
# 2  4-NOT SPECIFIED  Clerk#000000650               0
# 3         1-URGENT  Clerk#000000213               0
# 4  4-NOT SPECIFIED  Clerk#000000952               0
# 5         3-MEDIUM  Clerk#000000977               0
# 6            5-LOW  Clerk#000000872               0
# 7            5-LOW  Clerk#000000941               0
# 8           2-HIGH  Clerk#000000633               0
# 9            5-LOW  Clerk#000000719               0
#
#                                            o_comment
# 0  uests alongside of the ironic, ironic instruct...
# 1        ffix sometimes. regular ideas haggle carefu
# 2  d pearls. asymptotes haggle furiously regular ...
# 3                   carefully bold requests. careful
# 4  olites. unusual multipliers nag slyly even dep...
# 5  eposits haggle slyly? blithely final packages ...
# 6  l asymptotes nag stealthily. fluffily ironic r...
# 7  n foxes. theodolites integrate blithely. final...
# 8                        use quickly regular request
# 9            pinto beans. regular pinto beans along

# %%
# %%sql
# SELECT
#   o.o_orderkey,
#   l.l_orderkey
# FROM
#   orders o
#   JOIN lineitem l ON o.o_orderkey = l.l_orderkey
#   AND o.o_orderdate BETWEEN l.l_shipdate - INTERVAL '5' DAY AND l.l_shipdate  + INTERVAL '5' DAY
# LIMIT
#   10;
# Out:
#    o_orderkey  l_orderkey
# 0           7           7
# 1          32          32
# 2          33          33
# 3          69          69
# 4          71          71
# 5         132         132
# 6         133         133
# 7         198         198
# 8         259         259
# 9         260         260

# %%
# %%sql
# SELECT
#   COUNT(o.o_orderkey) AS order_rows_count,
#   COUNT(l.l_orderkey) AS lineitem_rows_count
# FROM
#   orders o
#   JOIN lineitem l ON o.o_orderkey = l.l_orderkey
#   AND o.o_orderdate BETWEEN l.l_shipdate - INTERVAL '5' DAY AND l.l_shipdate  + INTERVAL '5' DAY;
# -- 24613, 24613
# Out:
#    order_rows_count  lineitem_rows_count
# 0             24613                24613
